# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from skmlm import NN_MLM,MLM,FCM_MLM
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score,train_test_split
from sklearn.pipeline import make_pipeline

# %%
from sklearn.datasets import load_iris,load_wine,load_boston,load_breast_cancer

# %% [markdown]
# ## 1. Tester sur des problèmes de régressions

# %%
# normaliser les données 
def centrer_reduire(x):
    return (x-np.mean(x,axis=0))/np.std(x,axis=0)

# renvoie la moyenne des scores sur 10 fold pour différentes valeur de K
def test_cross(data,target):   
    L = []
    for i in range(1,11):  
        clf = make_pipeline(MinMaxScaler(),NN_MLM(rp_number=i/10))
        scores = cross_val_score(clf, data, target, cv=10, scoring='accuracy')
        L.append(scores.mean())
    return L

# calcule le mse pour les valeurs prédites pour différentes valeurs de K
# train_set = 2/3, test_set = 2/3
def test_mse(x,y):
    L = []
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.333, random_state=42)
    for i in range(1,11):
        clf = make_pipeline(MinMaxScaler(), NN_MLM(rp_number=i/10))
        clf.fit(x_train,y_train)
        y_pred = clf.predict(x_test)
        L.append(mean_squared_error(y_test,y_pred))
    return L

# %%
# charger quelques datasets utilisés dans l'article pour la régréssion, 
abalone = pd.read_csv("abalone.csv")
x = abalone.to_numpy()[:,1:7]# supprime les variables catégorielles
y = abalone.to_numpy()[:,8]
abalone = {'data':x,"target":y}# je transforme les données Abalone en dictionnaire 
boston = load_boston()
breast_cancer = load_breast_cancer()

#affichage des dimmensions 
print("abalone x : {}, y : {}".format(abalone['data'].shape,abalone['target'].shape))
print("boston  x : {}, y : {}".format(boston.data.shape,boston.target.shape))
print("breast_cancer  x : {}, y : {}".format(breast_cancer.data.shape,breast_cancer.target.shape))
# Out:
# abalone x : (4177, 6), y : (4177,)
# boston  x : (506, 13), y : (506,)
# breast_cancer  x : (569, 30), y : (569,)

# %% [markdown]
# ### Problèmes
# Je n'arrive pas à tester sur des problèmes de régressions, qu'on j'utilise la méthode MLM au lieux de NN_MLM comme vous pourrez le voir juste au dessus.
# Par contre pour les problèmes de classifications ç'a marche, en utilisant NN_MLM

# %%
x_train, x_test, y_train, y_test = train_test_split(boston.data, boston.target, test_size=0.333, random_state=42)
clf = make_pipeline(MinMaxScaler(), NN_MLM(rp_number=0.2))
clf.fit(x_train,y_train)
y_pred = clf.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-287-ae485e2418f7> in <module>
#       1 x_train, x_test, y_train, y_test = train_test_split(boston.data, boston.target, test_size=0.333, random_state=42)
#       2 clf = make_pipeline(MinMaxScaler(), NN_MLM(rp_number=0.2))
# ----> 3 clf.fit(x_train,y_train)
#       4 y_pred = clf.predict(x_test)
#
# ~\anaconda3\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     333             if self._final_estimator != 'passthrough':
#     334                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 335                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     336
#     337         return self
#
# ~\anaconda3\lib\site-packages\skmlm\mlm.py in fit(self, X, y)
#      85     def fit(self, X, y=None):
#      86         # convert outputs to one-hot encoding
# ...

# %%
#clf.fit(x_train,y_train)
#y_pred = clf.predict(x_test)
#print(mean_squared_error(y_test, y_pred))
L = test_mse(centrer_reduire(breast_cancer.data),centrer_reduire(breast_cancer.target))
plt.plot(np.arange(10,110,10),L,'-x')
plt.title("MSE per K/N %")
plt.xlabel("K/N %")
plt.ylabel("MSE")
plt.show()
print("dataset : breast_cancer")
print("best score is %.3f"%np.max(L))
# Out:
# dataset : breast_cancer
# best score is 2.243

# %% [markdown]
# ## 2. Tester sur des problèmes de classifications

# %%
# datasets avec des targets des valeurs discrêtes 
iris = load_iris()
wine = load_wine()

print("iris  x : {}, y : {}".format(iris.data.shape,iris.target.shape))
print("wine  x : {}, y : {}".format(wine.data.shape,wine.target.shape))
# Out:
# iris  x : (150, 4), y : (150,)
# wine  x : (178, 13), y : (178,)

# %%
L = test_cross(centrer_reduire(iris.data),iris.target)
plt.plot(np.arange(10,110,10),L,'-x')
plt.title("Accuracy per K/N %")
plt.xlabel("K/N %")
plt.ylabel("Accuracy")
plt.show()
print("dataset : iris")
print("best score is %.3f"%np.max(L))
# Out:
# dataset : iris
# best score is 0.953

# %%
L = test_cross(centrer_reduire(wine.data),wine.target)
plt.plot(np.arange(10,110,10),L,'-x')
plt.title("accuracy per K/N %")
plt.xlabel("K/N %")
plt.ylabel("Accuracy")
plt.show()
print("dataset : wine")
print("Best score %.3f"%np.max(L))
# Out:
# dataset : wine
# Best score 0.972

# %%
L_iris = test_mse(centrer_reduire(iris.data),iris.target)
L_wine = test_mse(centrer_reduire(wine.data),wine.target)

plt.plot(np.arange(10,110,10),L_iris,'-x',label='iris')
plt.plot(np.arange(10,110,10),L_wine,'-x',label='wine')
plt.legend()
plt.title("Mean square error per K/N")
plt.xlabel("K/N %")
plt.ylabel("MSE")
plt.show()

print("dataset : iris")
print("Best score %.3f"%np.max(L_iris))
print("dataset : wine")
print("Best score %.3f"%np.max(L_wine))
# Out:
# dataset : iris
# Best score 0.580
# dataset : wine
# Best score 0.017
